# %%
import pandas as pd

from google.colab import files
data1 = files.upload()
# Out:
#      <input type="file" id="files-360905b6-053c-4944-8533-9c544a4b4e2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-360905b6-053c-4944-8533-9c544a4b4e2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Game.csv to Game (3).csv

# %%
import io

# %% [markdown]
# # Game

# %%
Game = pd.read_csv(io.BytesIO(data1['Game.csv']))
Game.head()
# Out:
#     GAME_ID  SEASON_ID  ...  HUSTLE_STATUS HISTORICAL_STATUS
# 0  24600052      21946  ...              0                 1
# 1  24600063      21946  ...              0                 1
# 2  24600076      21946  ...              0                 1
# 3  24600078      21946  ...              0                 1
# 4  24600083      21946  ...              0                 1
#
# [5 rows x 50 columns]

# %%
#Drop some columns
Game = Game.drop(['TEAM_ID_HOME', 'TEAM_NAME_HOME', 'TEAM_NICKNAME_HOME', 'TEAM_CITY_NAME_HOME', 'HOME_TEAM_ID','TEAM_ID_AWAY', 'TEAM_NAME_AWAY','TEAM_NICKNAME_AWAY', 'TEAM_NICKNAME_AWAY', 'TEAM_CITY_NAME_AWAY', 'VISITOR_TEAM_ID','MATCHUP_HOME','MATCHUP_AWAY','PLUS_MINUS_HOME','PLUS_MINUS_AWAY','SEASON',
         'PTS_HOME_y', 'TEAM_WINS_LOSSES_HOME', 'TEAM_WINS_LOSSES_AWAY','GAME_DATE_EST','GAME_DATE_DAY','WL_AWAY','GAME_STATUS_ID','GAMECODE','LIVE_PERIOD','LIVE_PERIOD_TIME_BCAST',
         'WH_STATUS','HOME_TEAM_WINS','HOME_TEAM_LOSSES','VIDEO_AVAILABLE_FLAG','HUSTLE_STATUS','HISTORICAL_STATUS','PT_AVAILABLE','PT_XYZ_AVAILABLE'], axis=1)

# %% [markdown]
# # Seasons_Stats

# %%
from google.colab import files
data2 = files.upload()
# Out:
#      <input type="file" id="files-c05bcd82-c3d8-42f9-a8e3-0f6f5f2c4d26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c05bcd82-c3d8-42f9-a8e3-0f6f5f2c4d26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Seasons_stats.csv to Seasons_stats (1).csv

# %%
Seasons_Stats= pd.read_csv(io.BytesIO(data2['Seasons_stats.csv']))
Seasons_Stats.head()
# Out:
#    Year         Player  Pos  Age   Tm   G  ...  FTA    FT%  TRB  AST   PF   PTS
# 0  1950     Ed Bartels    F   24  NYK   2  ...    3  0.667  NaN    0    2     4
# 1  1950   Vince Boryla   SF   22  NYK  59  ...  267  0.764  NaN   95  203   612
# 2  1950     Carl Braun  G-F   22  NYK  67  ...  374  0.762  NaN  247  188  1031
# 3  1950       Bob Doll  F-C   30  BOS  47  ...  114  0.658  NaN  108  117   315
# 4  1950  Harry Donovan    G   23  NYK  45  ...  106  0.689  NaN   38  107   253
#
# [5 rows x 28 columns]

# %%
  Seasons_Stats=Seasons_Stats.drop(['WS','WS/48','FG%','2P%','FT%'],axis = 1)

# %%
Game.to_csv('Game.csv',index = False)
files.download('Game.csv')

# %%
Seasons_Stats.to_csv('Seasons_Stats.csv',index = False)
files.download('Seasons_Stats.csv')
